# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x=pd.read_csv("/content/sample_data/DATASET.csv")
x
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
x.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
x.tail()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 3644  Zimbabwe  2016                                42.561730
# 3645  Zimbabwe  2017                                44.178635
# 3646  Zimbabwe  2018                                45.572647
# 3647  Zimbabwe  2019                                46.781475
# 3648  Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 3644                               29.8
# 3645                               29.8
# 3646                               29.9
# 3647                               30.1
# 3648                               30.4
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 3644                                              62.88
# 3645                                              62.33
# 3646                                              82.53
# 3647                                              81.40
# 3648                                              80.61
# ...

# %%
x.shape
# Out:
# (3649, 21)

# %%
x.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
# ...

# %%
x.isnull()
# Out:
#       Entity   Year  Access to electricity (% of population)  \
# 0      False  False                                    False
# 1      False  False                                    False
# 2      False  False                                    False
# 3      False  False                                    False
# 4      False  False                                    False
# ...      ...    ...                                      ...
# 3644   False  False                                    False
# 3645   False  False                                    False
# 3646   False  False                                    False
# 3647   False  False                                    False
# 3648   False  False                                    False
#
#       Access to clean fuels for cooking  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# ...

# %%
x.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %%
x.notnull().sum()
# Out:
# Entity                                                              3649
# Year                                                                3649
# Access to electricity (% of population)                             3639
# Access to clean fuels for cooking                                   3480
# Renewable-electricity-generating-capacity-per-capita                2718
# Financial flows to developing countries (US $)                      1560
# Renewable energy share in the total final energy consumption (%)    3455
# Electricity from fossil fuels (TWh)                                 3628
# Electricity from nuclear (TWh)                                      3523
# Electricity from renewables (TWh)                                   3628
# Low-carbon electricity (% electricity)                              3607
# Primary energy consumption per capita (kWh/person)                  3649
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         3442
# ...

# %%
x.dropna()
# Out:
#           Entity  Year  Access to electricity (% of population)  \
# 43       Algeria  2001                                 98.96687
# 44       Algeria  2002                                 98.95306
# 45       Algeria  2003                                 98.93401
# 46       Algeria  2004                                 98.91208
# 47       Algeria  2005                                 98.88961
# ...          ...   ...                                      ...
# 3559  Uzbekistan  2015                                100.00000
# 3560  Uzbekistan  2016                                100.00000
# 3561  Uzbekistan  2017                                100.00000
# 3562  Uzbekistan  2018                                100.00000
# 3563  Uzbekistan  2019                                100.00000
#
#       Access to clean fuels for cooking  \
# 43                                97.30
# 44                                97.80
# 45                                98.00
# ...

# %%
x.head(6)
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
# 5  Afghanistan  2005                                25.390894
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
# 5                               12.2
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# ...

# %%
x.nunique()
# Out:
# Entity                                                               176
# Year                                                                  21
# Access to electricity (% of population)                             2040
# Access to clean fuels for cooking                                    896
# Renewable-electricity-generating-capacity-per-capita                2110
# Financial flows to developing countries (US $)                      1017
# Renewable energy share in the total final energy consumption (%)    2587
# Electricity from fossil fuels (TWh)                                 1859
# Electricity from nuclear (TWh)                                       547
# Electricity from renewables (TWh)                                   1533
# Low-carbon electricity (% electricity)                              2647
# Primary energy consumption per capita (kWh/person)                  3628
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         1044
# ...

# %%
x.value_counts
# Out:
# <bound method DataFrame.value_counts of            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# ...

# %%
x.sort_values
# Out:
# <bound method DataFrame.sort_values of            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# ...

# %%
x.fillna(0, inplace=True)
x
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
for column in x.columns[2:]:  # Iterate over all columns except the second one (index 1)
    x[column] = pd.to_numeric(x[column], errors='coerce')
x.to_csv('converted_dataset.csv', index=False)

# %%
x.fillna(0, inplace=True)

# %%
x1=x['Access to electricity (% of population)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Access to clean fuels for cooking']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Renewable-electricity-generating-capacity-per-capita']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Financial flows to developing countries (US $)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Electricity from fossil fuels (TWh)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Electricity from nuclear (TWh)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Electricity from fossil fuels (TWh)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Electricity from renewables (TWh)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Electricity from nuclear (TWh)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Low-carbon electricity (% electricity)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Primary energy consumption per capita (kWh/person)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
x1=x['Primary energy consumption per capita (kWh/person)']
y=x['Renewable energy share in the total final energy consumption (%)']
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
import seaborn as sns
sns.boxplot(data=x,x='Access to electricity (% of population)')
# Out:
# <Axes: xlabel='Access to electricity (% of population)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Access to clean fuels for cooking')
# Out:
# <Axes: xlabel='Access to clean fuels for cooking'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Renewable-electricity-generating-capacity-per-capita')
# Out:
# <Axes: xlabel='Renewable-electricity-generating-capacity-per-capita'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Electricity from fossil fuels (TWh)')
# Out:
# <Axes: xlabel='Electricity from fossil fuels (TWh)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Electricity from nuclear (TWh)')
# Out:
# <Axes: xlabel='Electricity from nuclear (TWh)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Electricity from renewables (TWh)')
# Out:
# <Axes: xlabel='Electricity from renewables (TWh)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Low-carbon electricity (% electricity)')
# Out:
# <Axes: xlabel='Low-carbon electricity (% electricity)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Primary energy consumption per capita (kWh/person)')
# Out:
# <Axes: xlabel='Primary energy consumption per capita (kWh/person)'>

# %%
import seaborn as sns
sns.boxplot(data=x,x='Energy intensity level of primary energy (MJ/$2017 PPP GDP)')
# Out:
# <Axes: xlabel='Energy intensity level of primary energy (MJ/$2017 PPP GDP)'>

# %%
import seaborn as sns
sns.histplot(x = "Access to electricity (% of population)", data=x)
# Out:
# <Axes: xlabel='Access to electricity (% of population)', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Access to clean fuels for cooking", data=x)
# Out:
# <Axes: xlabel='Access to clean fuels for cooking', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Renewable-electricity-generating-capacity-per-capita", data=x)
# Out:
# <Axes: xlabel='Renewable-electricity-generating-capacity-per-capita', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Financial flows to developing countries (US $)", data=x)
# Out:
# <Axes: xlabel='Financial flows to developing countries (US $)', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Access to electricity (% of population)", data=x)
# Out:
# <Axes: xlabel='Access to electricity (% of population)', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Electricity from fossil fuels (TWh)", data=x)
# Out:
# <Axes: xlabel='Electricity from fossil fuels (TWh)', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
x = x.iloc[:, 2:21]
y = x.iloc[:, 4:5]
print(x,'\n',y)
# Out:
#       Access to electricity (% of population)  \
# 0                                    1.613591
# 1                                    4.074574
# 2                                    9.409158
# 3                                   14.738506
# 4                                   20.064968
# ...                                       ...
# 3644                                42.561730
# 3645                                44.178635
# 3646                                45.572647
# 3647                                46.781475
# 3648                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# 3                                   9.5
# 4                                  10.9
# ...                                 ...
# 3644                               29.8
# 3645                               29.8
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2919, 19)
# (2919, 1)
# (730, 19)
# (730, 1)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
print(f"intercept: {lr_model.intercept_}")
print(f"coefficients: {lr_model.coef_}")
# Out:
# intercept: [2.89546165e-12]
# coefficients: [[ 2.31134472e-14  7.57869969e-14 -5.72045409e-15 -8.13975626e-21
#    1.00000000e+00 -1.06264772e-16  2.71308171e-14  1.48935882e-14
#   -1.12155435e-14 -2.73852766e-16  6.85243014e-14  1.97058103e-17
#   -1.04655030e-14  7.72862752e-15  3.42228762e-17 -5.28682916e-17
#   -8.21914352e-18 -2.06285230e-16  2.73839937e-16]]

# %%
#xgb
from xgboost import XGBRegressor
from math import sqrt
from sklearn import metrics
regressor = XGBRegressor()
regressor.fit(X_train, y_train)
# prediction on training data
training_data_prediction = regressor.predict(X_train)
mse = mean_squared_error(y_train,training_data_prediction)
xgb=(mse)
print("MSE of Training =",sqrt(xgb))
# R squared Value
r2_train = metrics.r2_score(y_train, training_data_prediction)
# prediction on test data
test_data_prediction = regressor.predict(X_test)
'''mse2 = mean_squared_error(Y_test,training_data_prediction)'''
'''print("MSE of test =",mse2)'''
# R squared Value
r2_test = metrics.r2_score(y_test, test_data_prediction)
print('R Squared value = ', r2_train)
print('R Squared value = ', r2_test)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MSE of Training = 0.05037120942289124
# R Squared value =  0.9999971712989518
# R Squared value =  0.999971958358799
# mae: 7.896085865216498e-12
# rmse: 1.516851216680887e-11

# %%
importance = pd.Series(regressor.feature_importances_)
importance.index = X_train.columns
importance.sort_values(inplace=True, ascending=False)
importance.head(10).plot.barh(figsize=(18,6))
# Out:
# <Axes: >

# %%
dtr_model = DecisionTreeRegressor()
dtr_model.fit(X_train, y_train)
y_pred = dtr_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.999993205174521

# %%
#linear regression
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
reg_all=linear_model.LinearRegression()
reg_all.fit(X_train,y_train)
y_pred=reg_all.predict(X_test)
lr=mean_squared_error(y_test,y_pred)
print("mse:",lr)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mse: 2.3008376135462866e-22
# mae: 7.896085865216498e-12
# rmse: 1.516851216680887e-11

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
cls=DecisionTreeRegressor()
cc=cls.fit(X_train,y_train)

# %%
from sklearn import tree
tree.plot_tree(cc,filled=True)
# Out:
# [Text(0.5629191568680891, 0.9666666666666667, 'x[4] <= 41.075\nsquared_error = 896.97\nsamples = 2919\nvalue = 31.01'),
#  Text(0.3213016858744744, 0.9, 'x[4] <= 16.01\nsquared_error = 148.196\nsamples = 1975\nvalue = 12.611'),
#  Text(0.16513198878679333, 0.8333333333333334, 'x[4] <= 5.75\nsquared_error = 22.4\nsamples = 1283\nvalue = 4.676'),
#  Text(0.0778475899392618, 0.7666666666666667, 'x[4] <= 2.195\nsquared_error = 2.976\nsamples = 800\nvalue = 1.413'),
#  Text(0.03547928671546488, 0.7, 'x[4] <= 0.79\nsquared_error = 0.4\nsamples = 581\nvalue = 0.465'),
#  Text(0.013675829310076312, 0.6333333333333333, 'x[4] <= 0.28\nsquared_error = 0.047\nsamples = 436\nvalue = 0.136'),
#  Text(0.004866843170845662, 0.5666666666666667, 'x[4] <= 0.075\nsquared_error = 0.003\nsamples = 340\nvalue = 0.027'),
#  Text(0.0017131287961376733, 0.5, 'x[4] <= 0.025\nsquared_error = 0.0\nsamples = 289\nvalue = 0.007'),
# ...

# %%
cl=cc.fit(X_train,y_train.values.ravel())

# %%
yp=cl.predict(X_test)
print(yp)
# Out:
# [1.057e+01 7.413e+01 7.310e+00 7.100e-01 1.720e+00 3.360e+00 0.000e+00
#  1.300e+01 1.873e+01 1.794e+01 1.036e+01 7.645e+01 5.742e+01 6.481e+01
#  2.619e+01 9.454e+01 3.912e+01 1.910e+00 1.190e+00 1.454e+01 3.540e+00
#  8.459e+01 6.213e+01 1.460e+00 1.812e+01 0.000e+00 2.070e+00 5.249e+01
#  7.964e+01 8.680e+00 4.147e+01 3.622e+01 6.639e+01 4.862e+01 1.720e+00
#  5.580e+01 1.540e+00 3.010e+00 6.000e-02 4.669e+01 9.640e+00 0.000e+00
#  7.990e+01 7.625e+01 0.000e+00 9.059e+01 9.363e+01 0.000e+00 4.009e+01
#  1.025e+01 5.343e+01 8.515e+01 7.150e+00 5.740e+00 5.467e+01 7.686e+01
#  9.411e+01 9.100e-01 8.036e+01 1.494e+01 2.480e+00 8.245e+01 8.370e+00
#  3.700e+00 1.794e+01 3.217e+01 9.000e-02 0.000e+00 3.599e+01 8.020e+00
#  1.392e+01 6.610e+00 0.000e+00 1.744e+01 3.622e+01 1.025e+01 8.189e+01
#  1.700e+00 3.520e+01 0.000e+00 1.933e+01 2.270e+00 3.217e+01 0.000e+00
#  6.069e+01 4.028e+01 0.000e+00 8.266e+01 8.320e+00 3.241e+01 5.900e-01
# ...

# %%
#decision tree
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
dt=mean_squared_error(y_test,yp )
print(dt)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.07855196343124803
# 0.006170410958904127
# 0.04679452054794532

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
kk=KNeighborsRegressor()
kl=kk.fit(X_train, y_train.values.ravel())

# %%
cl=cc.fit(X_train,y_train.values.ravel())

# %%
yp=kl.predict(X_test)
print(yp)
print(y_test)
# Out:
# [1.0942e+01 6.4720e+01 9.2780e+00 6.6400e-01 2.9060e+00 3.2760e+00
#  7.7840e+00 1.1202e+01 1.6142e+01 3.5830e+01 8.7080e+00 3.6444e+01
#  5.8676e+01 5.7930e+01 2.6944e+01 4.0176e+01 5.3172e+01 5.4060e+00
#  1.5380e+00 5.1448e+01 4.5688e+01 5.1234e+01 3.4598e+01 2.9060e+00
#  3.5830e+01 3.3000e-01 2.7360e+00 6.1874e+01 7.0972e+01 1.8920e+00
#  4.4616e+01 3.5184e+01 7.0384e+01 4.9388e+01 1.0540e+00 5.0162e+01
#  1.1880e+00 3.2740e+00 1.0400e-01 5.3474e+01 6.3520e+00 5.8000e-02
#  8.2258e+01 1.9710e+01 0.0000e+00 6.1018e+01 9.2944e+01 8.3800e-01
#  4.1680e+01 9.0780e+00 5.3006e+01 3.3628e+01 7.7840e+00 6.1612e+01
#  6.1874e+01 7.7100e+01 6.0184e+01 1.3980e+00 5.4520e+01 1.5702e+01
#  3.2580e+00 8.1422e+01 1.1174e+01 5.5500e+00 1.8266e+01 1.7410e+01
#  1.9710e+01 4.2822e+01 3.6046e+01 2.6968e+01 5.4360e+01 6.0440e+00
#  1.9844e+01 1.8160e+01 4.1992e+01 1.1588e+01 3.5342e+01 2.1100e+00
#  3.6094e+01 6.9658e+01 1.6892e+01 3.9240e+00 3.2604e+01 6.0972e+01
# ...

# %%
#KNN
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
knn=mean_squared_error(y_test,yp )
print(knn)
print(mean_absolute_error(y_test,yp ))
# Out:
# 22.463144731967407
# 504.592871249315
# 13.249421917808219

# %%
from sklearn.ensemble import RandomForestRegressor
rfc = RandomForestRegressor()

# %%
rr=rfc.fit(X_train,y_train.values.ravel())
yp=rr.predict(X_test)
print(yp)
# Out:
# [1.05902e+01 7.39941e+01 7.29020e+00 7.15100e-01 1.68620e+00 3.38970e+00
#  0.00000e+00 1.31511e+01 1.86862e+01 1.79117e+01 1.03594e+01 7.63825e+01
#  5.73606e+01 6.49204e+01 2.61974e+01 9.45482e+01 3.92230e+01 1.94770e+00
#  1.21840e+00 1.45889e+01 3.56130e+00 8.45850e+01 6.21221e+01 1.44700e+00
#  1.81244e+01 0.00000e+00 2.08590e+00 5.24303e+01 7.96917e+01 8.71620e+00
#  4.17556e+01 3.62035e+01 6.65437e+01 4.86454e+01 1.70080e+00 5.60581e+01
#  1.53060e+00 3.03140e+00 5.96000e-02 4.66477e+01 9.68620e+00 0.00000e+00
#  7.98215e+01 7.61744e+01 0.00000e+00 9.04583e+01 9.37211e+01 0.00000e+00
#  4.00761e+01 1.01961e+01 5.32259e+01 8.54666e+01 7.15250e+00 5.74170e+00
#  5.47483e+01 7.69631e+01 9.41403e+01 9.04200e-01 8.03119e+01 1.51404e+01
#  2.49330e+00 8.23584e+01 8.30620e+00 3.69310e+00 1.78609e+01 3.21913e+01
#  9.96000e-02 0.00000e+00 3.58575e+01 8.01570e+00 1.39307e+01 6.63740e+00
#  0.00000e+00 1.74906e+01 3.62084e+01 1.02269e+01 8.18836e+01 1.72150e+00
# ...

# %%
#Random forest
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
rf=mean_squared_error(y_test,yp )
print(rf)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.04246229802335729
# 0.0018030467534244127
# 0.026406712328766343

# %%
'''import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generate some sample data (replace this with your dataset)
x=pd.read_csv("/content/converted_dataset.csv")

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)

# Build a simple neural network model
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')



# Calculate the Mean Squared Error (MSE)
tf = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", tf)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))'''
# Out:
# Mean Squared Error: 2.3008376135462866e-22
# mae: 7.896085865216498e-12
# rmse: 1.516851216680887e-11

# %%
import numpy as np
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


# Split the data into training and testing sets
x=pd.read_csv("/content/converted_dataset.csv")

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)

# Create a Bayesian Ridge Regression model
model = BayesianRidge()

# Calculate the Mean Squared Error (MSE)
BR = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", BR)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error: 2.3008376135462866e-22
# mae: 7.896085865216498e-12
# rmse: 1.516851216680887e-11

# %%
import seaborn as sns
models = pd.DataFrame({
    'Model':['BayesianRidge','XGBRegressor', 'KNeighbours', 'Decision Trees', 'Random Forest'],
    'Error_score' :[BR,xgb, knn, dt, rf]
})
models
sns.barplot(x='Error_score', y='Model', data=models)
models.sort_values(by='Error_score', ascending=False)
# Out:
#             Model   Error_score
# 2     KNeighbours  5.045929e+02
# 3  Decision Trees  6.170411e-03
# 1    XGBRegressor  2.537259e-03
# 4   Random Forest  1.803047e-03
# 0   BayesianRidge  2.300838e-22
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Error_score'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...
